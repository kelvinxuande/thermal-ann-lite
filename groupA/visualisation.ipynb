# %% [markdown]
# # Data Visualisation of datasets in Group A
#
# Set 2 contains 2 datasets of data collected of 2 identical cells with the same load profile
#
# ### Import necessary libraries

# %%
import pandas as pd
import copy
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
# import codebase
import thermalModel_LDPRF as tm_LDPRF
import importlib
importlib.reload(tm_LDPRF)
# Out:
# <module 'thermalModel_LDPRF' from 'C:\\Users\\user\\Anaconda3\\lib\\thermalModel_LDPRF.py'>

# %% [markdown]
# ### Load 'AhCha','AhDch','Amb','Temp' data for both datasets

# %%
AhData_2097_df = tm_LDPRF.load_csv(filename = 'LDPRF_2097.csv', 
                                   features_list = ['second','AhCha','AhDch','Amb','Temp'], mode = 0)

AhData_2098_df = tm_LDPRF.load_csv(filename = 'LDPRF_2098.csv', 
                                   features_list = ['second','AhCha','AhDch','Amb','Temp'], mode = 0)
# Out:
# C:\Users\user\Anaconda3\lib\thermalModel_LDPRF.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['second'][set_index[index]:set_index[index+1]] = df['second'][set_index[index]:set_index[index+1]] + second_increment[index]
# C:\Users\user\Anaconda3\lib\thermalModel_LDPRF.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['second'][set_index[index]:] = df['second'][set_index[index]:] + second_increment[index]
# C:\Users\user\Anaconda3\lib\thermalModel_LDPRF.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %% [markdown]
# ### Visualise 'AhCha','AhDch','Amb','Temp' data for both datasets

# %%
AhData_2097_df.plot(title='LDPRF_2097', subplots=True, figsize=(20,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001DF9BA71860>,
# ...
#       dtype=object)

# %%
AhData_2098_df.plot(title='LDPRF_2098', subplots=True, figsize=(20,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001DFF8D03208>,
# ...
#       dtype=object)

# %%
AhData_2097_df[:75000].plot(title='LDPRF_2097', subplots=True, figsize=(20,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001DFFC9AFA90>,
# ...
#       dtype=object)

# %%
AhData_2098_df[:75000].plot(title='LDPRF_2098', subplots=True, figsize=(20,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001DFF8E69160>,
# ...
#       dtype=object)

# %%
AhData_2097_df[150000:250000].plot(title='LDPRF_2097', subplots=True, figsize=(20,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001DFF8E692E8>,
# ...
#       dtype=object)

# %%
AhData_2098_df[150000:250000].plot(title='LDPRF_2098', subplots=True, figsize=(20,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001DF80350E48>,
# ...
#       dtype=object)

# %%
AhData_2097_df.describe()
# Out:
#               second          AhCha          AhDch           Amb  \
# count  435839.000000  435839.000000  435839.000000  4.358390e+05
# mean    24468.740483     126.363856     144.644944  2.579465e+01
# std     11440.765250      72.924632      74.703530  2.402277e-10
# min         0.000000       0.000000       0.000000  2.579465e+01
# 25%     14564.850000      64.452000      81.299000  2.579465e+01
# 50%     24470.300000     126.039000     145.061000  2.579465e+01
# 75%     34375.750000     187.997000     208.479000  2.579465e+01
# max     44280.800000     252.040000     272.253000  2.579465e+01
#
#                 Temp
# count  435839.000000
# mean       34.312581
# std         2.060416
# min        25.794650
# 25%        33.008410
# 50%        35.085100
# 75%        35.850190
# max        36.724590

# %%
AhData_2098_df.describe()
# Out:
#               second          AhCha          AhDch           Amb  \
# count  435839.000000  435839.000000  435839.000000  4.358390e+05
# mean    20773.140869     126.437695     143.968215  2.626750e+01
# std     11367.928295      72.927347      74.268447  6.600594e-11
# min         0.000000       0.000000       0.000000  2.626750e+01
# 25%     10905.200000      64.531000      80.996500  2.626750e+01
# 50%     20810.600000     126.152000     144.421000  2.626750e+01
# 75%     30596.250000     188.089000     207.443000  2.626750e+01
# max     40501.400000     252.044000     270.765000  2.626750e+01
#
#                 Temp
# count  435839.000000
# mean       34.934164
# std         1.938317
# min        26.267500
# 25%        33.803260
# 50%        35.741030
# 75%        36.386950
# max        37.032870

# %% [markdown]
# ### Load 'Current','Voltage','Temp' data for both datasets

# %%
IVData_2097_df = tm_LDPRF.load_csv(filename = 'LDPRF_2097.csv', 
                                   features_list = ['second','Current','Voltage','Amb','Temp'], mode = 1)

IVData_2098_df = tm_LDPRF.load_csv(filename = 'LDPRF_2098.csv', 
                                   features_list = ['second','Current','Voltage','Amb','Temp'], mode = 1)
# Out:
# C:\Users\user\Anaconda3\lib\thermalModel_LDPRF.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['second'][set_index[index]:set_index[index+1]] = df['second'][set_index[index]:set_index[index+1]] + second_increment[index]
# C:\Users\user\Anaconda3\lib\thermalModel_LDPRF.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['second'][set_index[index]:] = df['second'][set_index[index]:] + second_increment[index]
# C:\Users\user\Anaconda3\lib\thermalModel_LDPRF.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %% [markdown]
# ### Visualise 'Current','Voltage','Temp' data for both datasets

# %%
IVData_2097_df.plot(title='LDPRF_2097', subplots=True, figsize=(20,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001DF974C20F0>,
# ...
#       dtype=object)

# %%
IVData_2098_df.plot(title='LDPRF_2098', subplots=True, figsize=(20,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001DFAD85BF28>,
# ...
#       dtype=object)

# %%
IVData_2097_df[:75000].plot(title='LDPRF_2097', subplots=True, figsize=(20,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001DFAD858278>,
# ...
#       dtype=object)

# %%
IVData_2098_df[:75000].plot(title='LDPRF_2098', subplots=True, figsize=(20,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001DF974D8198>,
# ...
#       dtype=object)

# %%
IVData_2097_df[150000:250000].plot(title='LDPRF_2097', subplots=True, figsize=(20,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001DF8C4DF668>,
# ...
#       dtype=object)

# %%
IVData_2098_df[150000:250000].plot(title='LDPRF_2098', subplots=True, figsize=(20,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001DF9753E1D0>,
# ...
#       dtype=object)

# %%
IVData_2097_df.describe()
IVData_2098_df.describe()
# Out:
#               second        Current        Voltage           Amb  \
# count  435839.000000  435839.000000  435839.000000  4.358390e+05
# mean    20773.140869      -0.497548       3.782469  2.626750e+01
# std     11367.928295      85.732075       0.086605  6.600594e-11
# min         0.000000    -176.603480       3.557440  2.626750e+01
# 25%     10905.200000       0.009560       3.741410  2.626750e+01
# 50%     20810.600000       0.009560       3.773560  2.626750e+01
# 75%     30596.250000       0.009560       3.813390  2.626750e+01
# max     40501.400000     222.893370       4.161120  2.626750e+01
#
#                 Temp
# count  435839.000000
# mean       34.934164
# std         1.938317
# min        26.267500
# 25%        33.803260
# 50%        35.741030
# 75%        36.386950
# max        37.032870
